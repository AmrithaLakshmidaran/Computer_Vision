# %%
import cv2

# Load the image using OpenCV
image_path ="C:/Users/student/Documents/Computer Vision 2023510051/Scene.jpg"
image = cv2.imread(image_path)

# %%
import cv2
import matplotlib.pyplot as plt

# Load the image using OpenCV
image_path ="C:/Users/student/Documents/Computer Vision 2023510051/Scene.jpg"
image = cv2.imread(image_path)

b, g, r = cv2.split(image)
   
    
print(f"B channel shape: {b.shape}")
print(f"G channel shape: {g.shape}")
print(f"R channel shape: {r.shape}")
   
    # Plot the individual color channels
plt.figure(figsize=(10, 4))

    # Plot Blue channel
plt.subplot(1, 3, 1)
plt.imshow(b, cmap='Blues')
plt.title('Blue Channel')
plt.axis('off')

    # Plot Green channel
plt.subplot(1, 3, 2)
plt.imshow(g, cmap='Greens')
plt.title('Green Channel')
plt.axis('off')

    # Plot Red channel
plt.subplot(1, 3, 3)
plt.imshow(r, cmap='Reds')
plt.title('Red Channel')
plt.axis('off')

    # Show the plots
plt.tight_layout()
plt.show()
# Out:
# B channel shape: (772, 809)
# G channel shape: (772, 809)
# R channel shape: (772, 809)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image
image_path = "C:/Users/student/Documents/Computer Vision 2023510051/Scene.jpg"
rgb_image = cv2.imread(image_path)

# Convert from BGR (OpenCV default) to RGB
rgb_image = cv2.cvtColor(rgb_image, cv2.COLOR_BGR2RGB)

# Split the image into Red, Green, and Blue channels
r, g, b = cv2.split(rgb_image)

# Print the shapes of the individual channels
print(f"R channel shape: {r.shape}")
print(f"G channel shape: {g.shape}")
print(f"B channel shape: {b.shape}")

# Modify the channels by setting the desired values to 0
# 1. Set Green and Blue channels to 0 (Remove green and blue)
rgb_image_gb_zero = cv2.merge([r, np.zeros_like(g), np.zeros_like(b)])

# 2. Set Red and Blue channels to 0 (Remove red and blue)
rgb_image_rb_zero = cv2.merge([np.zeros_like(r), g, np.zeros_like(b)])

# 3. Set Red and Green channels to 0 (Remove red and green)
rgb_image_rg_zero = cv2.merge([np.zeros_like(r), np.zeros_like(g), b])

# Display the modified images using OpenCV

# Plot the modified RGB images
plt.figure(figsize=(12, 4))

# Show the image with Green and Blue channels set to 0
plt.subplot(1, 3, 1)
plt.imshow(rgb_image_gb_zero)
plt.title("Green and Blue Set to 0")
plt.axis('off')

# Show the image with Red and Blue channels set to 0
plt.subplot(1, 3, 2)
plt.imshow(rgb_image_rb_zero)
plt.title("Red and Blue Set to 0")
plt.axis('off')

# Show the image with Red and Green channels set to 0
plt.subplot(1, 3, 3)
plt.imshow(rgb_image_rg_zero)
plt.title("Red and Green Set to 0")
plt.axis('off')

# Show the plots
plt.tight_layout()
plt.show()
# Out:
# R channel shape: (772, 809)
# G channel shape: (772, 809)
# B channel shape: (772, 809)

# %%
cmy=1-image
plt.imshow(cmy)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load image
image_path ="C:/Users/student/Documents/Computer Vision 2023510051/Scene.jpg"
image = cv2.imread(image_path)

# Convert RGB to CNY (Cyan, Magenta, Yellow by subtracting from 255)
cny_image = 255 - image

# Split the CNY image into Cyan, Magenta, Yellow channels
c, m, y = cv2.split(cny_image)

# Create individual color images for Cyan, Magenta, Yellow channels
cyan_img = cv2.merge([c, c, np.zeros_like(c)])
magenta_img = cv2.merge([np.zeros_like(m), m, m])
yellow_img = cv2.merge([y, np.zeros_like(y), y])

# Create a subplot to display all channels
fig, axes = plt.subplots(1, 5, figsize=(20, 6))

# Display the original image
axes[0].imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
axes[0].set_title("Original Image")
axes[0].axis('off')

# Display the Cyan channel
axes[1].imshow(cv2.cvtColor(cyan_img, cv2.COLOR_BGR2RGB))
axes[1].set_title("Cyan Channel")
axes[1].axis('off')

# Display the Magenta channel
axes[2].imshow(cv2.cvtColor(magenta_img, cv2.COLOR_BGR2RGB))
axes[2].set_title("Magenta Channel")
axes[2].axis('off')

# Display the Yellow channel
axes[3].imshow(cv2.cvtColor(yellow_img, cv2.COLOR_BGR2RGB))
axes[3].set_title("Yellow Channel")
axes[3].axis('off')

# Adjust layout and show the plot
plt.tight_layout()
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load image
image_path ="C:/Users/student/Documents/Computer Vision 2023510051/Scene.jpg"
image = cv2.imread(image_path)

# Convert from BGR (OpenCV default) to RGB
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# RGB to YIQ conversion matrix
# The matrix for converting RGB to YIQ is as follows:
# Y = 0.299 * R + 0.587 * G + 0.114 * B
# I = 0.5959 * R - 0.2746 * G - 0.3213 * B
# Q = 0.2115 * R - 0.5227 * G + 0.3112 * B

# We will use the matrix multiplication to convert RGB to YIQ
rgb_to_yiq_matrix = np.array([
    [0.299, 0.587, 0.114],   # Y coefficients
    [0.5959, -0.2746, -0.3213],  # I coefficients
    [0.2115, -0.5227, 0.3112]   # Q coefficients
])

# Perform matrix multiplication to convert each pixel from RGB to YIQ
yiq_image = np.dot(rgb_image / 255.0, rgb_to_yiq_matrix.T)

# Normalize the YIQ image to 0-255 scale for visualization
yiq_image = np.clip(yiq_image * 255, 0, 255).astype(np.uint8)

# Display the original image and YIQ image
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Original Image
axes[0].imshow(rgb_image)
axes[0].set_title("Original RGB Image")
axes[0].axis('off')

# YIQ Image
axes[1].imshow(yiq_image)
axes[1].set_title("YIQ Image")
axes[1].axis('off')

plt.tight_layout()
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image
image_path = "C:/Users/student/Documents/Computer Vision 2023510051/Scene.jpg"
rgb_image = cv2.imread(image_path)

# Convert from BGR (OpenCV default) to RGB
rgb_image = cv2.cvtColor(rgb_image, cv2.COLOR_BGR2RGB)

# Convert RGB to CMY (Cyan, Magenta, Yellow)
cmyk_image = 1 - rgb_image / 255.0  # Normalize to [0, 1] range and invert to get CMY

# Split the CMY channels
c, m, y = cv2.split(cmyk_image)

# Modify the channels as per your request
# 1. Set Cyan and Magenta channels to 0 (only Yellow remains)
cmyk_image_cy_mg_zero = cv2.merge([np.zeros_like(c), np.zeros_like(m), y])

# 2. Set Cyan and Yellow channels to 0 (only Magenta remains)
cmyk_image_cy_yl_zero = cv2.merge([np.zeros_like(c), m, np.zeros_like(y)])

# 3. Set Magenta and Yellow channels to 0 (only Cyan remains)
cmyk_image_mg_yl_zero = cv2.merge([c, np.zeros_like(m), np.zeros_like(y)])

# Convert the CMY images back to RGB for proper display
rgb_cy_mg_zero = 255 * (1 - np.dstack([cmyk_image_cy_mg_zero[:, :, 0], cmyk_image_cy_mg_zero[:, :, 1], cmyk_image_cy_mg_zero[:, :, 2]]))
rgb_cy_yl_zero = 255 * (1 - np.dstack([cmyk_image_cy_yl_zero[:, :, 0], cmyk_image_cy_yl_zero[:, :, 1], cmyk_image_cy_yl_zero[:, :, 2]]))
rgb_mg_yl_zero = 255 * (1 - np.dstack([cmyk_image_mg_yl_zero[:, :, 0], cmyk_image_mg_yl_zero[:, :, 1], cmyk_image_mg_yl_zero[:, :, 2]]))

# Plot the modified CMY images
plt.figure(figsize=(12, 4))

# Show the image with Cyan and Magenta set to 0 (Yellow Only)
plt.subplot(1, 3, 1)
plt.imshow(rgb_cy_mg_zero.astype(np.uint8))
plt.title("Yellow Only (Cyan and Magenta Set to 0)")
plt.axis('off')

# Show the image with Cyan and Yellow set to 0 (Magenta Only)
plt.subplot(1, 3, 2)
plt.imshow(rgb_cy_yl_zero.astype(np.uint8))
plt.title("Magenta Only (Cyan and Yellow Set to 0)")
plt.axis('off')

# Show the image with Magenta and Yellow set to 0 (Cyan Only)
plt.subplot(1, 3, 3)
plt.imshow(rgb_mg_yl_zero.astype(np.uint8))
plt.title("Cyan Only (Magenta and Yellow Set to 0)")
plt.axis('off')

# Show the plots
plt.tight_layout()
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load image
image_path =  "C:/Users/student/Documents/Computer Vision 2023510051/Scene.jpg"
image = cv2.imread(image_path)

# Split the image into BGR channels
b, g, r = cv2.split(image)

# Normalize the Red, Green, and Blue channels to the range [0, 1]
r_normalized = r / 255.0
g_normalized = g / 255.0
b_normalized = b / 255.0

# Optionally, convert them back to the range [0, 255] for visualization
r_normalized_scaled = (r_normalized * 255).astype(np.uint8)
g_normalized_scaled = (g_normalized * 255).astype(np.uint8)
b_normalized_scaled = (b_normalized * 255).astype(np.uint8)

# Display the original image and the normalized channels
fig, axes = plt.subplots(1, 4, figsize=(18, 6))

# Original Image
axes[0].imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
axes[0].set_title("Original Image")
axes[0].axis('off')

# Normalized Red Channel
axes[1].imshow(r_normalized_scaled, cmap='Reds')
axes[1].set_title("Normalized Red Channel")
axes[1].axis('off')

# Normalized Green Channel
axes[2].imshow(g_normalized_scaled, cmap='Greens')
axes[2].set_title("Normalized Green Channel")
axes[2].axis('off')

# Normalized Blue Channel
axes[3].imshow(b_normalized_scaled, cmap='Blues')
axes[3].set_title("Normalized Blue Channel")
axes[3].axis('off')

plt.tight_layout()
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load an image
image = cv2.imread( "C:/Users/student/Documents/Computer Vision 2023510051/Scene.jpg")  # Replace with your image path
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB

# Convert RGB to HSV
hsv_image = cv2.cvtColor(image, cv2.COLOR_RGB2HSV)

# Get the individual channels
h = hsv_image[:, :, 0]  # Hue channel
s = hsv_image[:, :, 1]  # Saturation channel
v = hsv_image[:, :, 2]  # Value channel

# Manually modify the Hue, Saturation, and Value
h = (h + 30) % 180  # Modify Hue by adding 30 and wrapping around using modulus 180 (OpenCV Hue range is 0-179)
s = np.clip(s + 50, 0, 255)  # Increase Saturation by 50, clipped to the range [0, 255]
v = np.clip(v + 50, 0, 255)  # Increase Value by 50, clipped to the range [0, 255]

# Reassemble the modified HSV image
modified_hsv_image = np.stack((h, s, v), axis=-1)

# Convert back to RGB
modified_rgb_image = cv2.cvtColor(modified_hsv_image, cv2.COLOR_HSV2RGB)

# Plot original and modified images
plt.figure(figsize=(10, 5))

# Original Image
plt.subplot(1, 2, 1)
plt.imshow(image)
plt.title('Original Image')
plt.axis('off')

# Modified Image
plt.subplot(1, 2, 2)
plt.imshow(modified_rgb_image)
plt.title('Modified Image (HSV Altered)')
plt.axis('off')

plt.show()
