# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# Load the RGB image
image_path = "C:/Users/student/Downloads/lena.jpg"  # Replace with your image path
rgb_image = cv2.cvtColor(cv2.imread(image_path), cv2.COLOR_BGR2RGB)

# Method 1: Average Grayscale
average_gray = np.mean(rgb_image, axis=2).astype(np.uint8)

# Method 2: Weighted Average Grayscale (standard weights for RGB)
weights = [0.2989, 0.5870, 0.1140]  # Standard weights for human perception
weighted_gray = np.dot(rgb_image[..., :3], weights).astype(np.uint8)

# Method 3: Using inbuilt function (OpenCV)
inbuilt_gray = cv2.cvtColor(rgb_image, cv2.COLOR_RGB2GRAY)

# Plot the results
plt.figure(figsize=(12, 8))

# Original RGB Image
plt.subplot(2, 2, 1)
plt.imshow(rgb_image)
plt.title("Original RGB Image")
plt.axis("off")

# Average Grayscale
plt.subplot(2, 2, 2)
plt.imshow(average_gray, cmap="gray")
plt.title("Average Grayscale")
plt.axis("off")

# Weighted Average Grayscale
plt.subplot(2, 2, 3)
plt.imshow(weighted_gray, cmap="gray")
plt.title("Weighted Average Grayscale")
plt.axis("off")

# Inbuilt Grayscale
plt.subplot(2, 2, 4)
plt.imshow(inbuilt_gray, cmap="gray")
plt.title("Inbuilt Grayscale")
plt.axis("off")

plt.tight_layout()
plt.show()

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# Load the image
image_path = "C:/Users/student/Downloads/lena.jpg"
image = cv2.imread(image_path)

# Convert to grayscale
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Perform histogram equalization
equalized_image = cv2.equalizeHist(gray_image)

# Plot the original and equalized images along with their histograms
fig, axes = plt.subplots(2, 2, figsize=(10, 10))

# Original Image
axes[0, 0].imshow(gray_image, cmap='gray')
axes[0, 0].set_title('Original Image')
axes[0, 0].axis('off')

# Equalized Image
axes[0, 1].imshow(equalized_image, cmap='gray')
axes[0, 1].set_title('Equalized Image')
axes[0, 1].axis('off')

# Histogram of the original image
axes[1, 0].hist(gray_image.ravel(), bins=256, color='gray')
axes[1, 0].set_title('Histogram of Original Image')

# Histogram of the equalized image
axes[1, 1].hist(equalized_image.ravel(), bins=256, color='gray')
axes[1, 1].set_title('Histogram of Equalized Image')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# Load the image
image_path = "C:/Users/student/Downloads/lena.jpg"
image = cv2.imread(image_path)

# Convert the image from BGR to RGB (OpenCV loads images in BGR by default)
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Split the image into its RGB channels
r, g, b = cv2.split(rgb_image)

# Perform histogram equalization on each channel
r_equalized = cv2.equalizeHist(r)
g_equalized = cv2.equalizeHist(g)
b_equalized = cv2.equalizeHist(b)

# Merge the equalized channels back together
equalized_rgb_image = cv2.merge([r_equalized, g_equalized, b_equalized])

# Plot the original and equalized images along with their histograms
fig, axes = plt.subplots(2, 2, figsize=(10, 10))

# Original Image
axes[0, 0].imshow(rgb_image)
axes[0, 0].set_title('Original RGB Image')
axes[0, 0].axis('off')

# Equalized Image
axes[0, 1].imshow(equalized_rgb_image)
axes[0, 1].set_title('Equalized RGB Image')
axes[0, 1].axis('off')

# Histogram of the original image (for each channel)
axes[1, 0].hist(r.ravel(), bins=256, color='red', alpha=0.5, label='Red')
axes[1, 0].hist(g.ravel(), bins=256, color='green', alpha=0.5, label='Green')
axes[1, 0].hist(b.ravel(), bins=256, color='blue', alpha=0.5, label='Blue')
axes[1, 0].set_title('Histogram of Original RGB Image')
axes[1, 0].legend()

# Histogram of the equalized image (for each channel)
axes[1, 1].hist(r_equalized.ravel(), bins=256, color='red', alpha=0.5, label='Red')
axes[1, 1].hist(g_equalized.ravel(), bins=256, color='green', alpha=0.5, label='Green')
axes[1, 1].hist(b_equalized.ravel(), bins=256, color='blue', alpha=0.5, label='Blue')
axes[1, 1].set_title('Histogram of Equalized RGB Image')
axes[1, 1].legend()

plt.tight_layout()
plt.show()

# %% [raw]
# USING BUILT IN FUNCTION

# %%
import cv2
import matplotlib.pyplot as plt

# Load the image
image_path = "C:/Users/student/Downloads/lena.jpg"
image = cv2.imread(image_path)

# Convert the image from BGR to RGB (OpenCV loads images in BGR by default)
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Convert to grayscale using OpenCV's built-in function
gray_image_builtin = cv2.cvtColor(rgb_image, cv2.COLOR_RGB2GRAY)

# Plot the original and grayscale images
plt.figure(figsize=(10, 5))

# Original RGB Image
plt.subplot(1, 2, 1)
plt.imshow(rgb_image)
plt.title('Original RGB Image')
plt.axis('off')

# Grayscale Image using OpenCV
plt.subplot(1, 2, 2)
plt.imshow(gray_image_builtin, cmap='gray')
plt.title('Grayscale Image (Built-in)')
plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# WITHOUT USING THE BUILT IN FUNCTION

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image
image_path = "C:/Users/student/Downloads/lena.jpg"
image = cv2.imread(image_path)

# Convert the image from BGR to RGB (OpenCV loads images in BGR by default)
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Manually convert RGB to grayscale using the luminance formula
# Grayscale = 0.299*R + 0.587*G + 0.114*B
r, g, b = rgb_image[:,:,0], rgb_image[:,:,1], rgb_image[:,:,2]
gray_image_manual = 0.299 * r + 0.587 * g + 0.114 * b

# Plot the original and grayscale images
plt.figure(figsize=(10, 5))

# Original RGB Image
plt.subplot(1, 2, 1)
plt.imshow(rgb_image)
plt.title('Original RGB Image')
plt.axis('off')

# Grayscale Image (Manual)
plt.subplot(1, 2, 2)
plt.imshow(gray_image_manual, cmap='gray')
plt.title('Grayscale Image (Manual)')
plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
#  Resizing an RGB Image Using OpenCV's Built-In Function

# %%
import cv2
import matplotlib.pyplot as plt

# Load the image
image_path = "C:/Users/student/Downloads/lena.jpg"
image = cv2.imread(image_path)

# Convert the image from BGR to RGB (OpenCV loads images in BGR by default)
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Resize the RGB image using OpenCV's resize function
resized_rgb_image = cv2.resize(rgb_image, (256, 256))  # Resize to 256x256

# Plot the original and resized images
plt.figure(figsize=(10, 5))

# Original RGB Image
plt.subplot(1, 2, 1)
plt.imshow(rgb_image)
plt.title('Original RGB Image')
plt.axis('off')

# Resized RGB Image
plt.subplot(1, 2, 2)
plt.imshow(resized_rgb_image)
plt.title('Resized RGB Image (OpenCV)')
plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
#  Manually Resizing an RGB Image (Without OpenCV)

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# Load the image
image_path = "C:/Users/student/Downloads/lena.jpg"
image = Image.open(image_path)

# Convert to RGB if not already in RGB mode
rgb_image = image.convert('RGB')

# Resize the image manually using PIL
resized_rgb_image_manual = rgb_image.resize((256, 256))

# Convert resized image back to NumPy array for plotting
resized_rgb_image_manual = np.array(resized_rgb_image_manual)

# Plot the original and resized images
plt.figure(figsize=(10, 5))

# Original RGB Image
plt.subplot(1, 2, 1)
plt.imshow(np.array(rgb_image))
plt.title('Original RGB Image')
plt.axis('off')

# Resized RGB Image (Manual)
plt.subplot(1, 2, 2)
plt.imshow(resized_rgb_image_manual)
plt.title('Resized RGB Image (Manual)')
plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
#  Resizing a Grayscale Image Using OpenCV's Built-In Function

# %%
import cv2
import matplotlib.pyplot as plt

# Load the image
image_path = "C:/Users/student/Downloads/lena.jpg"
image = cv2.imread(image_path)

# Convert the image to grayscale using OpenCV
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Resize the grayscale image using OpenCV's resize function
resized_gray_image = cv2.resize(gray_image, (256, 256))  # Resize to 256x256

# Plot the original and resized images
plt.figure(figsize=(10, 5))

# Original Grayscale Image
plt.subplot(1, 2, 1)
plt.imshow(gray_image, cmap='gray')
plt.title('Original Grayscale Image')
plt.axis('off')

# Resized Grayscale Image
plt.subplot(1, 2, 2)
plt.imshow(resized_gray_image, cmap='gray')
plt.title('Resized Grayscale Image (OpenCV)')
plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
#  Manually Resizing a Grayscale Image (Without OpenCV)

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# Load the image
image_path = "C:/Users/student/Downloads/lena.jpg"
image = Image.open(image_path)

# Convert to grayscale using PIL
gray_image = image.convert('L')

# Resize the grayscale image manually using PIL
resized_gray_image_manual = gray_image.resize((256, 256))

# Convert resized image back to NumPy array for plotting
resized_gray_image_manual = np.array(resized_gray_image_manual)

# Plot the original and resized images
plt.figure(figsize=(10, 5))

# Original Grayscale Image
plt.subplot(1, 2, 1)
plt.imshow(np.array(gray_image), cmap='gray')
plt.title('Original Grayscale Image')
plt.axis('off')

# Resized Grayscale Image (Manual)
plt.subplot(1, 2, 2)
plt.imshow(resized_gray_image_manual, cmap='gray')
plt.title('Resized Grayscale Image (Manual)')
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# Load the image
image_path = "C:/Users/student/Downloads/lena.jpg"  # Replace with your Lena image path
image = cv2.imread(image_path)

# Convert the image from BGR to RGB (OpenCV loads images in BGR by default)
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Split the image into its RGB channels
r, g, b = cv2.split(rgb_image)

# Perform histogram equalization on each channel
r_equalized = cv2.equalizeHist(r)
g_equalized = cv2.equalizeHist(g)
b_equalized = cv2.equalizeHist(b)

# Merge the equalized channels back together
equalized_rgb_image = cv2.merge([r_equalized, g_equalized, b_equalized])

# Plot the original and equalized images along with their histograms for each color channel
fig, axes = plt.subplots(2, 3, figsize=(12, 10))

# Histogram for the Red channel (Original)
axes[0, 0].hist(r.ravel(), bins=256, color='red', alpha=0.7)
axes[0, 0].set_title('Red Channel Histogram (Original)')

# Histogram for the Green channel (Original)
axes[0, 1].hist(g.ravel(), bins=256, color='green', alpha=0.7)
axes[0, 1].set_title('Green Channel Histogram (Original)')

# Histogram for the Blue channel (Original)
axes[0, 2].hist(b.ravel(), bins=256, color='blue', alpha=0.7)
axes[0, 2].set_title('Blue Channel Histogram (Original)')

# Histogram for the Red channel (Equalized)
axes[1, 0].hist(r_equalized.ravel(), bins=256, color='red', alpha=0.7)
axes[1, 0].set_title('Red Channel Histogram (Equalized)')

# Histogram for the Green channel (Equalized)
axes[1, 1].hist(g_equalized.ravel(), bins=256, color='green', alpha=0.7)
axes[1, 1].set_title('Green Channel Histogram (Equalized)')

# Histogram for the Blue channel (Equalized)
axes[1, 2].hist(b_equalized.ravel(), bins=256, color='blue', alpha=0.7)
axes[1, 2].set_title('Blue Channel Histogram (Equalized)')

# Show the plot
plt.tight_layout()
plt.show()
